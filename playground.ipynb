# %%
import yaml

# %%
file = open("225171.yaml", 'r')
data = yaml.load(file)
# Out:
# C:\Users\hitesh.gulati\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
data
# Out:
# {'meta': {'data_version': 0.9,
#   'created': datetime.date(2015, 12, 9),
#   'revision': 1},
#  'info': {'city': 'Belfast',
#   'dates': [datetime.date(2006, 6, 13)],
#   'gender': 'male',
#   'match_type': 'ODI',
#   'outcome': {'by': {'runs': 38}, 'winner': 'England'},
#   'overs': 50,
#   'player_of_match': ['ME Trescothick'],
#   'teams': ['Ireland', 'England'],
#   'toss': {'decision': 'bat', 'winner': 'England'},
#   'umpires': ['R Dill', 'DB Hair'],
#   'venue': 'Civil Service Cricket Club, Stormont'},
#  'innings': [{'1st innings': {'team': 'England',
#     'deliveries': [{0.1: {'batsman': 'ME Trescothick',
#        'bowler': 'DT Johnston',
#        'non_striker': 'EC Joyce',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.2: {'batsman': 'ME Trescothick',
#        'bowler': 'DT Johnston',
#        'non_striker': 'EC Joyce',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.3: {'batsman': 'ME Trescothick',
# ...

# %%
type(data)
# Out:
# dict

# %%
def findnondict (variable):
    print(type(variable))
    if isinstance(variable,dict) : findnondict(variable[list(variable)[0]])

# %%
list(data)
# Out:
# ['meta', 'info', 'innings']

# %%
data[list(data)[0]]
# Out:
# {'data_version': 0.9, 'created': datetime.date(2015, 12, 9), 'revision': 1}

# %%
findnondict(data)
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'float'>
